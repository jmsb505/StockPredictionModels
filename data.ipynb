# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
from datetime import timedelta

# %%
dft= pd.read_csv("Tweets/Tweet.csv")
dfct=pd.read_csv("Tweets/Company_Tweet.csv")
df=pd.merge(dft, dfct, on='tweet_id', how='inner')
df.head()
# Out:
#              tweet_id           writer   post_date  \
# 0  550441509175443456  VisualStockRSRC  1420070457
# 1  550441672312512512      KeralaGuy77  1420070496
# 2  550441732014223360      DozenStocks  1420070510
# 3  550442977802207232     ShowDreamCar  1420070807
# 4  550443807834402816     i_Know_First  1420071005
#
#                                                 body  comment_num  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1  Insanity of today weirdo massive selling. $aap...            0
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...            0
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...            0
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...            0
#
#    retweet_num  like_num ticker_symbol
# 0            0         1          AAPL
# 1            0         0          AAPL
# 2            0         0          AMZN
# 3            0         1          TSLA
# 4            0         1          AAPL

# %%
df=df[["tweet_id","ticker_symbol","post_date","body","comment_num","retweet_num","like_num"]]
df.head()
# Out:
#              tweet_id ticker_symbol   post_date  \
# 0  550441509175443456          AAPL  1420070457
# 1  550441672312512512          AAPL  1420070496
# 2  550441732014223360          AMZN  1420070510
# 3  550442977802207232          TSLA  1420070807
# 4  550443807834402816          AAPL  1420071005
#
#                                                 body  comment_num  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1  Insanity of today weirdo massive selling. $aap...            0
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...            0
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...            0
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...            0
#
#    retweet_num  like_num
# 0            0         1
# 1            0         0
# 2            0         0
# 3            0         1
# 4            0         1

# %%
df['post_date'] = pd.to_datetime(df['post_date'], unit='s')
df['post_date'] = df['post_date'].dt.date
df['post_date'] = df['post_date'] + timedelta(days=-1)
df.head()
# Out:
#              tweet_id ticker_symbol   post_date  \
# 0  550441509175443456          AAPL  2014-12-31
# 1  550441672312512512          AAPL  2014-12-31
# 2  550441732014223360          AMZN  2014-12-31
# 3  550442977802207232          TSLA  2014-12-31
# 4  550443807834402816          AAPL  2014-12-31
#
#                                                 body  comment_num  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1  Insanity of today weirdo massive selling. $aap...            0
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...            0
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...            0
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...            0
#
#    retweet_num  like_num
# 0            0         1
# 1            0         0
# 2            0         0
# 3            0         1
# 4            0         1

# %%
has_null = df.isna().any().any()
print(has_null)
# Out:
# False

# %% [markdown]
# Datos generales:

# %%
df["ticker_symbol"].hist(figsize=(10,8))
df.hist(figsize=(10,8))
plt.show()

# %%
print(df['post_date'].value_counts().mean())
# Out:
# 2374.8329682365825

# %%
apple=df[df['ticker_symbol']=='AAPL']
apple.hist(figsize=(10,8),bins=25)
plt.show()

# %%
print(apple['post_date'].value_counts().mean())
# Out:
# 783.4046179219351

# %%
amazon=df[df['ticker_symbol']=='AMZN']
amazon.hist(figsize=(10,8),bins=25)
plt.show()

# %%
print(amazon['post_date'].value_counts().mean())
# Out:
# 393.60076670317636

# %%
tesla=df[df['ticker_symbol']=='TSLA']
tesla.hist(figsize=(10,8),bins=25)
plt.show()

# %%
print(tesla['post_date'].value_counts().mean())
# Out:
# 600.6944140197152

# %%
microsoft=df[df['ticker_symbol']=='MSFT']
microsoft.hist(figsize=(10,8),bins=25)
plt.show()

# %%
print(microsoft['post_date'].value_counts().mean())
# Out:
# 205.75629791894852

# %%
google=df[df['ticker_symbol']=='GOOGL']
google.hist(figsize=(10,8),bins=25)
plt.show()

# %%
print(google['post_date'].value_counts().mean())
# Out:
# 179.39156626506025

# %%
goog=df[df['ticker_symbol']=='GOOG']
goog.hist(figsize=(10,8),bins=25)
plt.show()

# %%
print(goog['post_date'].value_counts().mean())
# Out:
# 215.10630136986302

# %%
df.to_csv("Data/CompanyTweets.csv", index=False)
